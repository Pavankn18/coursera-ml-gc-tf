# %% [markdown]
# # Neural Network

# %% [markdown]
# **Learning Objectives:**
#   * Use the `DNNRegressor` class in TensorFlow to predict median housing price

# %% [markdown]
# The data is based on 1990 census data from California. This data is at the city block level, so these features reflect the total number of rooms in that block, or the total number of people who live on that block, respectively.
# <p>
# Let's use a set of features to predict house value.

# %% [markdown]
# ## Set Up
# In this first cell, we'll load the necessary libraries.

# %%
import math
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:.1f}'.format
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Next, we'll load our data set.

# %%
df = pd.read_csv("https://storage.googleapis.com/ml_universities/california_housing_train.csv", sep=",")

# %% [markdown]
# ## Examine the data
#
# It's a good idea to get to know your data a little bit before you work with it.
#
# We'll print out a quick summary of a few useful statistics on each column.
#
# This will include things like mean, standard deviation, max, min, and various quantiles.

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0            1.5             66900.0
# 1      1129.0       463.0            1.8             80100.0
# 2       333.0       117.0            1.7             85700.0
# 3       515.0       226.0            3.2             73400.0
# 4       624.0       262.0            1.9             65500.0

# %%
df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9            207300.9
# std        1147.9       384.5            1.9            115983.8
# min           3.0         1.0            0.5             14999.0
# 25%         790.0       282.0            2.6            119400.0
# 50%        1167.0       409.0            3.5            180400.0
# 75%        1721.0       605.2            4.8            265000.0
# max       35682.0      6082.0           15.0            500001.0

# %% [markdown]
# This data is at the city block level, so these features reflect the total number of rooms in that block, or the total number of people who live on that block, respectively.  Let's create a different, more appropriate feature.  Because we are predicing the price of a single house, we should try to make all our features correspond to a single house as well

# %%
df['num_rooms'] = df['total_rooms'] / df['households']
df['num_bedrooms'] = df['total_bedrooms'] / df['households']
df['persons_per_house'] = df['population'] / df['households']
df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value  num_rooms  \
# count     17000.0     17000.0        17000.0             17000.0    17000.0
# mean       1429.6       501.2            3.9            207300.9        5.4
# std        1147.9       384.5            1.9            115983.8        2.5
# min           3.0         1.0            0.5             14999.0        0.8
# 25%         790.0       282.0            2.6            119400.0        4.4
# 50%        1167.0       409.0            3.5            180400.0        5.2
# 75%        1721.0       605.2            4.8            265000.0        6.1
# max       35682.0      6082.0           15.0            500001.0      141.9
#
#        num_bedrooms  persons_per_house
# count       17000.0            17000.0
# mean            1.1                3.0
# std             0.5                4.0
# min             0.3                0.7
# 25%             1.0                2.4
# 50%             1.0                2.8
# 75%             1.1                3.3
# max            34.1              502.5

# %%
df.drop(['total_rooms', 'total_bedrooms', 'population', 'households'], axis = 1, inplace = True)
df.describe()
# Out:
#        longitude  latitude  housing_median_age  median_income  \
# count    17000.0   17000.0             17000.0        17000.0
# mean      -119.6      35.6                28.6            3.9
# std          2.0       2.1                12.6            1.9
# min       -124.3      32.5                 1.0            0.5
# 25%       -121.8      33.9                18.0            2.6
# 50%       -118.5      34.2                29.0            3.5
# 75%       -118.0      37.7                37.0            4.8
# max       -114.3      42.0                52.0           15.0
#
#        median_house_value  num_rooms  num_bedrooms  persons_per_house
# count             17000.0    17000.0       17000.0            17000.0
# mean             207300.9        5.4           1.1                3.0
# std              115983.8        2.5           0.5                4.0
# min               14999.0        0.8           0.3                0.7
# 25%              119400.0        4.4           1.0                2.4
# 50%              180400.0        5.2           1.0                2.8
# 75%              265000.0        6.1           1.1                3.3
# max              500001.0      141.9          34.1              502.5

# %% [markdown]
# ## Build a neural network model
#
# In this exercise, we'll be trying to predict `median_house_value`. It will be our label (sometimes also called a target). We'll use the remaining columns as our input features.
#
# To train our model, we'll first use the [LinearRegressor](https://www.tensorflow.org/api_docs/python/tf/contrib/learn/LinearRegressor) interface. Then, we'll change to DNNRegressor

# %%
featcols = {
  colname : tf.feature_column.numeric_column(colname) \
    for colname in 'housing_median_age,median_income,num_rooms,num_bedrooms,persons_per_house'.split(',')
}
# Bucketize lat, lon so it's not so high-res; California is mostly N-S, so more lats than lons
featcols['longitude'] = tf.feature_column.bucketized_column(tf.feature_column.numeric_column('longitude'),
                                                   np.linspace(-124.3, -114.3, 5).tolist())
featcols['latitude'] = tf.feature_column.bucketized_column(tf.feature_column.numeric_column('latitude'),
                                                  np.linspace(32.5, 42, 10).tolist())

# %%
featcols.keys()
# Out:
# dict_keys(['longitude', 'num_bedrooms', 'median_income', 'latitude', 'persons_per_house', 'num_rooms', 'housing_median_age'])

# %%
# Split into train and eval
msk = np.random.rand(len(df)) < 0.8
traindf = df[msk]
evaldf = df[~msk]

SCALE = 100000
BATCH_SIZE= 100
OUTDIR = './housing_trained'
train_input_fn = tf.estimator.inputs.pandas_input_fn(x = traindf[list(featcols.keys())],
                                                    y = traindf["median_house_value"] / SCALE,
                                                    num_epochs = None,
                                                    batch_size = BATCH_SIZE,
                                                    shuffle = True)
eval_input_fn = tf.estimator.inputs.pandas_input_fn(x = evaldf[list(featcols.keys())],
                                                    y = evaldf["median_house_value"] / SCALE,  # note the scaling
                                                    num_epochs = 1, 
                                                    batch_size = len(evaldf), 
                                                    shuffle=False)

# %%
# Linear Regressor
def train_and_evaluate(output_dir, num_train_steps):
  myopt = tf.train.FtrlOptimizer(learning_rate = 0.01) # note the learning rate
  estimator = tf.estimator.LinearRegressor(
                       model_dir = output_dir, 
                       feature_columns = featcols.values(),
                       optimizer = myopt)
  
  #Add rmse evaluation metric
  def rmse(labels, predictions):
    pred_values = tf.cast(predictions['predictions'],tf.float64)
    return {'rmse': tf.metrics.root_mean_squared_error(labels*SCALE, pred_values*SCALE)}
  estimator = tf.contrib.estimator.add_metrics(estimator,rmse)
  
  train_spec=tf.estimator.TrainSpec(
                       input_fn = train_input_fn,
                       max_steps = num_train_steps)
  eval_spec=tf.estimator.EvalSpec(
                       input_fn = eval_input_fn,
                       steps = None,
                       start_delay_secs = 1, # start evaluating after N seconds
                       throttle_secs = 10,  # evaluate every N seconds
                       )
  tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# Run training    
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time
train_and_evaluate(OUTDIR, num_train_steps = (100 * len(traindf)) / BATCH_SIZE)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc37b6de630>, '_train_distribute': None, '_model_dir': './housing_trained', '_num_ps_replicas': 0, '_tf_random_seed': None, '_keep_checkpoint_every_n_hours': 10000, '_global_id_in_cluster': 0, '_service': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_master': '', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_task_id': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_is_chief': True}
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc37b6cfe48>, '_train_distribute': None, '_model_dir': './housing_trained', '_num_ps_replicas': 0, '_tf_random_seed': None, '_keep_checkpoint_every_n_hours': 10000, '_master': '', '_save_summary_steps': 100, '_session_config': None, '_save_checkpoints_secs': 600, '_keep_checkpoint_max': 5, '_service': None, '_save_checkpoints_steps': None, '_global_id_in_cluster': 0, '_task_id': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_is_chief': True}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 10 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into ./housing_trained/model.ckpt.
# INFO:tensorflow:step = 1, loss = 713.05066
# INFO:tensorflow:global_step/sec: 240.136
# INFO:tensorflow:step = 101, loss = 152.4431 (0.419 sec)
# INFO:tensorflow:global_step/sec: 324.511
# INFO:tensorflow:step = 201, loss = 42.507023 (0.308 sec)
# INFO:tensorflow:global_step/sec: 357.343
# INFO:tensorflow:step = 301, loss = 75.19721 (0.280 sec)
# INFO:tensorflow:global_step/sec: 375.788
# INFO:tensorflow:step = 401, loss = 102.14687 (0.266 sec)
# INFO:tensorflow:global_step/sec: 336.115
# INFO:tensorflow:step = 501, loss = 91.99134 (0.298 sec)
# INFO:tensorflow:global_step/sec: 354.794
# INFO:tensorflow:step = 601, loss = 98.02701 (0.282 sec)
# INFO:tensorflow:global_step/sec: 366.877
# INFO:tensorflow:step = 701, loss = 60.655567 (0.273 sec)
# INFO:tensorflow:global_step/sec: 373.745
# INFO:tensorflow:step = 801, loss = 56.483353 (0.268 sec)
# INFO:tensorflow:global_step/sec: 341.211
# INFO:tensorflow:step = 901, loss = 40.23432 (0.292 sec)
# INFO:tensorflow:global_step/sec: 356.947
# INFO:tensorflow:step = 1001, loss = 75.24569 (0.280 sec)
# INFO:tensorflow:global_step/sec: 370.879
# INFO:tensorflow:step = 1101, loss = 39.90978 (0.270 sec)
# INFO:tensorflow:global_step/sec: 376.501
# INFO:tensorflow:step = 1201, loss = 91.13809 (0.266 sec)
into ./housing_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 31.128553.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-04-15:42:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./housing_trained/model.ckpt-11949
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-05-04-15:42:16
# INFO:tensorflow:Saving dict for global step 11949: average_loss = 0.58455294, global_step = 11949, loss = 1979.2963, rmse = 76456.055
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./housing_trained/model.ckpt-11949
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 11950 into ./housing_trained/model.ckpt.
# INFO:tensorflow:step = 11950, loss = 80.05311
# INFO:tensorflow:global_step/sec: 238.493
# INFO:tensorflow:step = 12050, loss = 31.732819 (0.423 sec)
# INFO:tensorflow:global_step/sec: 368.874
# INFO:tensorflow:step = 12150, loss = 127.71507 (0.270 sec)
# INFO:tensorflow:global_step/sec: 345.873
# INFO:tensorflow:step = 12250, loss = 17.72047 (0.291 sec)
# INFO:tensorflow:global_step/sec: 356.116
# INFO:tensorflow:step = 12350, loss = 94.71319 (0.279 sec)
# INFO:tensorflow:global_step/sec: 359.894
# INFO:tensorflow:step = 12450, loss = 55.13491 (0.278 sec)
# INFO:tensorflow:global_step/sec: 367.199
# INFO:tensorflow:step = 12550, loss = 70.19656 (0.273 sec)
# INFO:tensorflow:global_step/sec: 339.017
# INFO:tensorflow:step = 12650, loss = 65.23266 (0.294 sec)
# INFO:tensorflow:global_step/sec: 343.099
# INFO:tensorflow:step = 12750, loss = 44.74261 (0.291 sec)
# INFO:tensorflow:global_step/sec: 374.433
# INFO:tensorflow:step = 12850, loss = 65.80793 (0.267 sec)
# INFO:tensorflow:global_step/sec: 345.133
# INFO:tensorflow:step = 12950, loss = 67.53488 (0.290 sec)
# INFO:tensorflow:global_step/sec: 360.042
# INFO:tensorflow:step = 13050, loss = 68.948616 (0.279 sec)
# INFO:tensorflow:global_step/sec: 359.013
# INFO:tensorflow:step = 13150, loss = 51.091503 (0.277 sec)
# INFO:tensorflow:global_step/sec: 351.646
# INFO:tensorflow:step = 13250, loss = 26.567467 (0.285 sec)
# INFO:tensorflow:global_step/sec: 335.893
# INFO:tensorflow:step = 13350, loss = 35.41706 (0.297 sec)
# INFO:tensorflow:global_step/sec: 343.986
# INFO:tensorflow:step = 13450, loss = 107.70412 (0.291 sec)
# INFO:tensorflow:global_step/sec: 363.181
# INFO:tensorflow:step = 13550, loss = 43.491512 (0.275 sec)
# INFO:tensorflow:Saving checkpoints for 13614 into ./housing_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 21.201864.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-04-15:42:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./housing_trained/model.ckpt-13614
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-05-04-15:42:23
# INFO:tensorflow:Saving dict for global step 13614: average_loss = 0.5829711, global_step = 13614, loss = 1973.9402, rmse = 76352.555

# %%
# DNN Regressor
def train_and_evaluate(output_dir, num_train_steps):
  myopt = tf.train.FtrlOptimizer(learning_rate = 0.01) # note the learning rate
  estimator = tf.estimator.DNNRegressor(model_dir = output_dir,
                                hidden_units = [100, 50, 20],
                                feature_columns = featcols.values(),
                                optimizer = myopt,
                                dropout = 0.1)
  
  #Add rmse evaluation metric
  def rmse(labels, predictions):
    pred_values = tf.cast(predictions['predictions'],tf.float64)
    return {'rmse': tf.metrics.root_mean_squared_error(labels*SCALE, pred_values*SCALE)}
  estimator = tf.contrib.estimator.add_metrics(estimator,rmse)
  
  train_spec=tf.estimator.TrainSpec(
                       input_fn = train_input_fn,
                       max_steps = num_train_steps)
  eval_spec=tf.estimator.EvalSpec(
                       input_fn = eval_input_fn,
                       steps = None,
                       start_delay_secs = 1, # start evaluating after N seconds
                       throttle_secs = 10,  # evaluate every N seconds
                       )
  tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# Run training    
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time
tf.summary.FileWriterCache.clear() # ensure filewriter cache is clear for TensorBoard events file
train_and_evaluate(OUTDIR, num_train_steps = (100 * len(traindf)) / BATCH_SIZE)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc37653e4e0>, '_train_distribute': None, '_model_dir': './housing_trained', '_num_ps_replicas': 0, '_tf_random_seed': None, '_keep_checkpoint_every_n_hours': 10000, '_global_id_in_cluster': 0, '_service': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_master': '', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_task_id': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_is_chief': True}
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc37653e470>, '_train_distribute': None, '_model_dir': './housing_trained', '_num_ps_replicas': 0, '_tf_random_seed': None, '_keep_checkpoint_every_n_hours': 10000, '_master': '', '_save_summary_steps': 100, '_session_config': None, '_save_checkpoints_secs': 600, '_keep_checkpoint_max': 5, '_service': None, '_save_checkpoints_steps': None, '_global_id_in_cluster': 0, '_task_id': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_is_chief': True}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 10 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into ./housing_trained/model.ckpt.
# INFO:tensorflow:step = 1, loss = 945.08856
# INFO:tensorflow:global_step/sec: 208.784
# INFO:tensorflow:step = 101, loss = 78.72485 (0.484 sec)
# INFO:tensorflow:global_step/sec: 281.541
# INFO:tensorflow:step = 201, loss = 87.74535 (0.355 sec)
# INFO:tensorflow:global_step/sec: 297.488
# INFO:tensorflow:step = 301, loss = 43.56634 (0.336 sec)
# INFO:tensorflow:global_step/sec: 261.982
# INFO:tensorflow:step = 401, loss = 69.56576 (0.382 sec)
# INFO:tensorflow:global_step/sec: 284.219
# INFO:tensorflow:step = 501, loss = 54.269867 (0.352 sec)
# INFO:tensorflow:global_step/sec: 296.465
# INFO:tensorflow:step = 601, loss = 83.4727 (0.338 sec)
# INFO:tensorflow:global_step/sec: 261.099
# INFO:tensorflow:step = 701, loss = 50.497658 (0.382 sec)
# INFO:tensorflow:global_step/sec: 294.737
# INFO:tensorflow:step = 801, loss = 42.158707 (0.339 sec)
# INFO:tensorflow:global_step/sec: 296.439
# INFO:tensorflow:step = 901, loss = 50.58397 (0.337 sec)
# INFO:tensorflow:global_step/sec: 271.106
# INFO:tensorflow:step = 1001, loss = 102.73271 (0.369 sec)
# INFO:tensorflow:global_step/sec: 284.629
# INFO:tensorflow:step = 1101, loss = 53.30237 (0.351 sec)
# INFO:tensorflow:global_step/sec: 280.584
# INFO:tensorflow:step = 1201, loss = 61.428345 (0.362 sec)
# INFO:tensorflow:global_step/sec: 272.529
# INFO:tensorflow:step = 1301, loss = 41.710205 (0.362 sec)
# INFO:tensorflow:global_step/sec: 291.02
# INFO:tensorflow:step = 1401, loss = 69.86579 (0.344 sec)
# INFO:tensorflow:global_step/sec: 266.419
